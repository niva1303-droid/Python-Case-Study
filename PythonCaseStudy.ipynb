# %% [markdown]
# <a href="https://colab.research.google.com/github/niva1303-droid/Python-Case-Study/blob/Case-Study/PythonCaseStudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case Study – Student ID Card Generator
# # Instructions:
#
# • Create variables: student_name, roll_number, department
#
# • Take input from the user using input() function
#
# • Convert student_name and department into uppercase using upper()
#
# • Extract first 4 letters of student_name and department using slicing
#
# • Create Student ID by combining name, department, and roll number
#
# • Display Name, Department, Roll Number, and Student ID only
#
# • Use print() and f-string for output display

# %%
student_name = input("Enter Student Name: ")
roll_number = input("Enter Roll Number: ")
department_name = input("Enter Department Name: ")

upper_student_name = student_name.upper()
upper_department_name = department_name.upper()

first_4_name = student_name[0:4]
first_4_department = department_name[0:4]

student_id = first_4_name + '_' + roll_number + '_' + first_4_department

# Display Output

print("\n------Student ID Card Generator------")

print(f"Student Name = {upper_student_name}")
print(f"Department Name = {upper_department_name}")
print(f"Roll Number = {roll_number}")
print(f"Student ID = {student_id}")
# Out:
# Enter Student Name: Amit Kumar
# Enter Roll Number: 1101
# Enter Department Name: Physics
#
# ------Student ID Card Generator------
# Student Name = AMIT KUMAR
# Department Name = PHYSICS
# Roll Number = 1101
# Student ID = Amit_1101_Phys
